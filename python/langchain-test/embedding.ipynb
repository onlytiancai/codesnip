, -0.04530993849039078, -0.06086801365017891, 0.10767341405153275, -0.06464602798223495, -0.035838667303323746, -0.05037352815270424, -0.03408084064722061, -0.04685787484049797, 0.017683207988739014, 0.15626287460327148, -0.09775612503290176, -0.005437455140054226, -0.09271877259016037, -0.05924136936664581, 0.01790621504187584, -0.0979660153388977, -0.07372375577688217, -0.024806339293718338, 0.005142297595739365, 0.03670446202158928, -0.0034435028210282326, -0.04412930831313133, 0.02823016420006752, -0.0136559484526515, 0.051868993788957596, 0.054046597331762314, -0.0632292702794075, -0.08023034036159515, -0.09649679064750671, -0.06595783680677414, 0.0536530539393425, 0.039695389568805695, 0.03875088691711426, 0.1168036162853241, 0.011255335062742233, 0.038882065564394, -0.00751011585816741, -0.019008135423064232, -0.11019209027290344, -0.04643809422850609, 0.004306018352508545, 0.0020923379343003035, 0.012376933358609676, -0.03938055410981178, 0.0053915418684482574, -0.09067235141992569, 0.030748840421438217, -0.10473495721817017, -0.05614549294114113, -0.0024957198183983564, 0.05362681671977043, -0.003223774489015341, 0.05315456539392471, -0.04176805168390274, -0.005234124604612589, 0.05420401319861412, -0.03864594176411629, -0.022550024092197418, -0.07477320730686188, -0.020962733775377274, 0.0007091976003721356, -0.06894876807928085, 0.08878334611654282, -0.052997149527072906, 0.012757358141243458, -0.010868350975215435, 0.0027433240320533514, -0.08930806815624237, -0.012153925374150276, 0.076294906437397, -0.14608323574066162, -0.08699928224086761, 0.05897900462150574, 0.07340892404317856, 0.16707220673561096, -0.1380024701356 ...

# %%
words = ["java", "javascript", "python"]

response = client.embeddings.create(
    model="text-embedding-3-small",
    dimensions=256,
    input=words
)
embeddings = [item.embedding for item in response.data]

def cosine_similarity(vec1, vec2):
    v1, v2 = np.array(vec1), np.array(vec2)
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

for i in range(len(words)):
    for j in range(i + 1, len(words)):
        sim = cosine_similarity(embeddings[i], embeddings[j])
        print(f"Similarity({words[i]}, {words[j]}) = {sim:.4f}")
# Out:
# Similarity(java, javascript) = 0.5951
# Similarity(java, python) = 0.4965
# Similarity(javascript, python) = 0.4202

# %%
# !pip install --upgrade tiktoken -q

# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokens_from_string("machine learning", "cl100k_base")
# Out:
# 2
